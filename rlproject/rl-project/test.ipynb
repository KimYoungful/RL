# %%
from ultralytics import YOLO

# Create a new YOLO model from scratch
model = YOLO("runs/detect/train3/weights/last.pt")




# Perform object detection on an image using the model
results = model.predict("dataset\\images\\train\\img0.jpg",imgsz=640)

# Export the model to ONNX format
# success = model.export(format="onnx")
# Out:
# image 1/1 c:\Users\admin\Desktop\huifeng\rlproject\rl-project\dataset\images\train\img0.jpg: 640x512 (no detections), 33.9ms
# Speed: 1.4ms preprocess, 33.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 512)
