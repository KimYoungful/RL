# %%
import numpy as np
import gymnasium as gym
from gymnasium import spaces
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import time
import random
import pygame
from loguru import logger

# --- Constants ---
SCREEN_WIDTH = 1200
SCREEN_HEIGHT = 800
FPS = 60

# Colors
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)
RED = (220, 50, 50)
GREEN = (50, 220, 50)
BLUE = (50, 50, 220)
GRAY = (150, 150, 150)

# %%
import gymnasium as gym
from gymnasium.spaces import Box, Discrete,Tuple
import numpy as np
import pygame

# Define colors
WHITE = (255, 255, 255)
RED = (255, 0, 0)
GREEN = (0, 255, 0)
BLUE = (0, 0, 255)  # Color for the trajectory

class CustomEnv(gym.Env):
    metadata = {"render_modes": ["human", "rgb_array"], "render_fps": 60}

    def __init__(self):
        super().__init__()
        self.grid_size = 10
        self.obstacle_num = 8
        self.distance_threshold_goal = 0.3  # Tolerance for goal proximity

        # Define two separate thresholds for obstacle handling
        self.distance_threshold_penalty = 1  # Penalty zone threshold (larger value)
        self.distance_threshold_collision = 0.5  # Collision threshold (smaller value)
        self.penalty_factor = 25  # Penalty scaling factor

        self.steps = 0

        self.pre_distance = 0  # Previous distance to goal, used for reward shaping
        self.current_distance = 0  # Current distance to goal, used for reward shaping
        # Action space (dx, dy)
        self.action_space = spaces.Box(low=-1, high=1, shape=(2,), dtype=np.float32)
        # Observation space (robot_x, robot_y, goal_x, goal_y)
        self.observation_shape = 2 + 2 + 1+self.obstacle_num * 2  # Robot position, goal position, and obstacle positions
        self.observation_space = Box(low=0, high=self.grid_size, shape=(self.observation_shape,), dtype=np.float32)

        
        # For rendering
        self.window = None
        self.clock = None
        self.cell_size = 50 # Pixels per grid unit
        self.trajectory_points = [] # New: List to store past robot positions

    def _get_obs(self):
   
        return np.concatenate(([self.robot_position]+ [self.goal_position]+[np.array([self.closest_obstacle_distance])]+self.obstacle_position),dtype=np.float32)

    def _get_info(self):
        return {
            "distance_to_goal": np.linalg.norm(self.robot_position - self.goal_position)
        }

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.robot_position = np.random.uniform(0, self.grid_size, size=2)
        self.goal_position = np.random.uniform(0, self.grid_size, size=2)
        self.obstacle_position = [np.random.uniform(0, self.grid_size, size=2) for _ in range(self.obstacle_num)]
        self.closest_obstacle_distance = np.min([np.linalg.norm(self.robot_position - obs) for obs in self.obstacle_position])
        self.steps = 0
        self.trajectory_points = [self.robot_position.copy()] # New: Reset trajectory and add initial position
        self.pre_distance = np.linalg.norm(self.robot_position - self.goal_position)
        self.max_steps = 1000  # Set a maximum number of steps to prevent infinite loops
        return self._get_obs(), self._get_info()

    def _reward(self):
        terminated = False
        truncated = False
        reward = 0  # Initialize reward
        done_reason = None  # Initialize done reason
        if self.steps >= self.max_steps:
            reward -= 50
            truncated = True  # Truncate if max steps reached
        
        

        if np.any(self.robot_position <= 0.0) or np.any(self.grid_size-self.robot_position <=0.0):
            reward -= 100
            terminated = True
            done_reason = "Out of bounds"

        self.robot_position = np.clip(self.robot_position, 0, self.grid_size)

        # Auxiliary Rewards -  distance to goal
        self.current_distance = np.linalg.norm(self.robot_position - self.goal_position)
        reward += (self.pre_distance - self.current_distance)*40  # Reward shaping based on distance change
        self.pre_distance = self.current_distance

        # Obstacle handling with two thresholds
        self.closest_obstacle_distance = np.min([np.linalg.norm(self.robot_position - obs) for obs in self.obstacle_position])
        for obs in self.obstacle_position:
            distance = np.linalg.norm(self.robot_position - obs)
            if distance < self.distance_threshold_collision:
                # Game over - collision detected
                reward -= 150  # Large negative reward for collision
                terminated = True
                done_reason = "Collision with obstacle"
                break
            elif distance < self.distance_threshold_penalty:
                reward -= (self.distance_threshold_penalty - distance)* 200  # 或者更大
        
             
        
        if np.linalg.norm(self.robot_position - self.goal_position) < self.distance_threshold_goal:
            reward += 100
            terminated = True
            done_reason = "Reached the goal"
        
        reward-=  0.5  # Small penaty for  each step to encourage efficiency

        return reward,terminated,truncated,done_reason
        

    def step(self, action):
        stride = 0.3  # Base stride length
        self.robot_position += action * stride  # Scale the action to control speed

        self.trajectory_points.append(self.robot_position.copy()) # New: Add current position to trajectory

        reward,terminated,truncated,done_reason = self._reward()

        info = self._get_info()
        observation = self._get_obs()
        self.steps += 0.01

        # if terminated or truncated:
        #     logger.warning(f"Episode ended: {done_reason}, Steps: {self.steps:.2f}")
        return observation, reward, terminated, truncated, info

    def render(self):
        if self.window is None:
            pygame.init()
            pygame.display.init()
            self.window = pygame.display.set_mode(
                (int(self.grid_size * self.cell_size), int(self.grid_size * self.cell_size))
            )
            pygame.display.set_caption("CustomEnv")
        if self.clock is None:
            self.clock = pygame.time.Clock()
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                import sys
                sys.exit() # Exit the program
            elif event.type == pygame.MOUSEBUTTONDOWN:
                if event.button == 1: # Left mouse button click
                    mouse_x, mouse_y = event.pos # Get mouse position in pixels
                    # Convert pixel coordinates to grid coordinates
                    new_goal_x = mouse_x / self.cell_size
                    new_goal_y = mouse_y / self.cell_size
                    self.goal_position = np.array([new_goal_x, new_goal_y], dtype=np.float32)
                    print(f"New goal set at grid position: {self.goal_position}")


        canvas = pygame.Surface((self.grid_size * self.cell_size, self.grid_size * self.cell_size))
        canvas.fill(WHITE)
        virus_image = pygame.image.load("病毒.png").convert_alpha()  # Load an image if needed, but not used here
        robot_image = pygame.transform.scale(virus_image, (int(self.cell_size * 0.8), int(self.cell_size * 0.8)))  # Scale the image
        # New: Draw the trajectory
        if len(self.trajectory_points) > 1:
            scaled_points = []
            for point in self.trajectory_points:
                scaled_points.append((int(point[0] * self.cell_size), int(point[1] * self.cell_size)))
            
            # Draw lines between consecutive points
            pygame.draw.lines(canvas, BLUE, False, scaled_points, 2) # Blue line, not closed, 2 pixels wide
            
            # Optionally, draw small circles at each point to emphasize
            for point_coord in scaled_points:
                pygame.draw.circle(canvas, BLUE, point_coord, 3) # Small blue circles

        # Draw robot
        pygame.draw.circle(
            canvas,
            RED,
            (int(self.robot_position[0] * self.cell_size), int(self.robot_position[1] * self.cell_size)),
            int(self.cell_size * 0.2)
        )
        # Draw obstacles
        for obs in self.obstacle_position:
            # pygame.draw.circle(
            #     canvas,
            #     GRAY,
            #     (int(obs[0] * self.cell_size), int(obs[1] * self.cell_size)),
            #     int(self.cell_size * 0.5)
            # )
            canvas.blit(robot_image, (int(obs[0] * self.cell_size), int(obs[1] * self.cell_size)))
        # Draw goal
        pygame.draw.circle(
            canvas,
            GREEN,
            (int(self.goal_position[0] * self.cell_size), int(self.goal_position[1] * self.cell_size)),
            int(self.cell_size * 0.3)
        )

        self.window.blit(canvas, canvas.get_rect())
        pygame.event.pump()
        pygame.display.flip()
        self.clock.tick(self.metadata["render_fps"])

    def close(self):
        if self.window is not None:
            pygame.display.quit()
            pygame.quit()

# %%
import gymnasium as gym
import torch
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.monitor import Monitor


env =DummyVecEnv([lambda: Monitor(CustomEnv())])  # Wrap the environment with Monitor for logging
policy_kwargs = dict(
    net_arch=[dict(pi=[64,128], vf=[128,128])],
    # activation_fn=torch.nn.ReLU  # 改为 ReLU，通常更适合稀疏奖励
)

model = PPO("MlpPolicy", env, verbose=1, ent_coef=0.005,policy_kwargs=policy_kwargs,tensorboard_log="./ppo_custom_env_tensorboard/")
# model.load("logs/best_model/best_model.zip",env=env)  # Load the best model
eval_callback = EvalCallback(
    env,
    best_model_save_path='./logs/best_model2/',
    log_path = './logs/',
    eval_freq=100000,  # 每1000步评估一次
    deterministic=True,
    render=False,
    n_eval_episodes=5,  # 每次评估5个episode
)

model.learn(total_timesteps=5000000,callback=eval_callback)
# env.save("vec_env.pkl")  # Save the environment state
# vec_env = model.get_env()
# obs = vec_env.reset()
# for i in range(1000):
#     action, _states = model.predict(obs, deterministic=True)
#     obs, reward, dones, info = vec_env.step(action)
    # vec_env.render()


env.close()
# Out:
# Using cpu device
# Logging to ./ppo_custom_env_tensorboard/PPO_36
# g:\anaconda\envs\RL\lib\site-packages\stable_baselines3\common\policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | -286     |
# | time/              |          |
# |    fps             | 2801     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 90.6       |
# |    ep_rew_mean          | -281       |
# | time/                   |            |
# |    fps                  | 1919       |
# |    iterations           | 2          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01353144 |
# |    clip_fraction        | 0.148      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.83      |
# |    explained_variance   | 0.00111    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 833        |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0155    |
# |    std                  | 0.997      |
# |    value_loss           | 4.56e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 78.3        |
# |    ep_rew_mean          | -327        |
# | time/                   |             |
# |    fps                  | 1768        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009514181 |
# |    clip_fraction        | 0.089       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0.000898    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.64e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 0.998       |
# |    value_loss           | 5.27e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.1        |
# |    ep_rew_mean          | -345        |
# | time/                   |             |
# |    fps                  | 1694        |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008336352 |
# |    clip_fraction        | 0.053       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 9.42e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.85e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00975    |
# |    std                  | 0.999       |
# |    value_loss           | 1.11e+04    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 62.2      |
# |    ep_rew_mean          | -329      |
# | time/                   |           |
# |    fps                  | 1654      |
# |    iterations           | 5         |
# |    time_elapsed         | 6         |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.0334502 |
# |    clip_fraction        | 0.119     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.83     |
# |    explained_variance   | 2.6e-05   |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.29e+03  |
# |    n_updates            | 40        |
# |    policy_gradient_loss | -0.00904  |
# |    std                  | 0.993     |
# |    value_loss           | 5.83e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 63.5        |
# |    ep_rew_mean          | -313        |
# | time/                   |             |
# |    fps                  | 1613        |
# |    iterations           | 6           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008024331 |
# |    clip_fraction        | 0.0807      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 3.48e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.4e+03     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.994       |
# |    value_loss           | 9.35e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.6        |
# |    ep_rew_mean          | -291        |
# | time/                   |             |
# |    fps                  | 1594        |
# |    iterations           | 7           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008221441 |
# |    clip_fraction        | 0.0711      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | -1.86e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.95e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00964    |
# |    std                  | 0.994       |
# |    value_loss           | 1.02e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 64.3        |
# |    ep_rew_mean          | -292        |
# | time/                   |             |
# |    fps                  | 1577        |
# |    iterations           | 8           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010734383 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | -9.54e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01e+04    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00728    |
# |    std                  | 0.988       |
# |    value_loss           | 1.15e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.9        |
# |    ep_rew_mean          | -262        |
# | time/                   |             |
# |    fps                  | 1568        |
# |    iterations           | 9           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011996549 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.00321     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.42e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.984       |
# |    value_loss           | 5.85e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 66.5        |
# |    ep_rew_mean          | -285        |
# | time/                   |             |
# |    fps                  | 1547        |
# |    iterations           | 10          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005869448 |
# |    clip_fraction        | 0.0386      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.0538      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.08e+03    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00749    |
# |    std                  | 0.991       |
# |    value_loss           | 6.4e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 75.5         |
# |    ep_rew_mean          | -305         |
# | time/                   |              |
# |    fps                  | 1544         |
# |    iterations           | 11           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0052782437 |
# |    clip_fraction        | 0.0341       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.119        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.73e+03     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00551     |
# |    std                  | 0.994        |
# |    value_loss           | 8.23e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 85.3       |
# |    ep_rew_mean          | -290       |
# | time/                   |            |
# |    fps                  | 1548       |
# |    iterations           | 12         |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.00986798 |
# |    clip_fraction        | 0.107      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.82      |
# |    explained_variance   | 0.317      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.39e+03   |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0133    |
# |    std                  | 0.991      |
# |    value_loss           | 3.62e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87.1        |
# |    ep_rew_mean          | -339        |
# | time/                   |             |
# |    fps                  | 1546        |
# |    iterations           | 13          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.019003466 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.0201      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 303         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0215     |
# |    std                  | 0.985       |
# |    value_loss           | 908         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 89.9         |
# |    ep_rew_mean          | -378         |
# | time/                   |              |
# |    fps                  | 1549         |
# |    iterations           | 14           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0052096862 |
# |    clip_fraction        | 0.0306       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | -0.0118      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.43e+03     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00909     |
# |    std                  | 0.987        |
# |    value_loss           | 1.79e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.1        |
# |    ep_rew_mean          | -332        |
# | time/                   |             |
# |    fps                  | 1548        |
# |    iterations           | 15          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008878815 |
# |    clip_fraction        | 0.0769      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.0892      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.57e+03    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0094     |
# |    std                  | 0.984       |
# |    value_loss           | 8.72e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 68.6         |
# |    ep_rew_mean          | -341         |
# | time/                   |              |
# |    fps                  | 1545         |
# |    iterations           | 16           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0050329473 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.204        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.86e+03     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00847     |
# |    std                  | 0.986        |
# |    value_loss           | 7.01e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 77.1         |
# |    ep_rew_mean          | -339         |
# | time/                   |              |
# |    fps                  | 1544         |
# |    iterations           | 17           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0065491614 |
# |    clip_fraction        | 0.0612       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.317        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.37e+03     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00892     |
# |    std                  | 0.992        |
# |    value_loss           | 7.62e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 70.3        |
# |    ep_rew_mean          | -330        |
# | time/                   |             |
# |    fps                  | 1543        |
# |    iterations           | 18          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008361961 |
# |    clip_fraction        | 0.0877      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.149       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.31e+03    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.996       |
# |    value_loss           | 8.95e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 54.3         |
# |    ep_rew_mean          | -285         |
# | time/                   |              |
# |    fps                  | 1544         |
# |    iterations           | 19           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0074598817 |
# |    clip_fraction        | 0.0633       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.211        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.35e+03     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00794     |
# |    std                  | 0.995        |
# |    value_loss           | 5.52e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.9        |
# |    ep_rew_mean          | -234        |
# | time/                   |             |
# |    fps                  | 1542        |
# |    iterations           | 20          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007433623 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.116       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.31e+03    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.988       |
# |    value_loss           | 3.14e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 58           |
# |    ep_rew_mean          | -248         |
# | time/                   |              |
# |    fps                  | 1540         |
# |    iterations           | 21           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0081340885 |
# |    clip_fraction        | 0.067        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.81        |
# |    explained_variance   | 0.212        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.29e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.0102      |
# |    std                  | 0.986        |
# |    value_loss           | 4.62e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 72.5        |
# |    ep_rew_mean          | -292        |
# | time/                   |             |
# |    fps                  | 1540        |
# |    iterations           | 22          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.009776057 |
# |    clip_fraction        | 0.0966      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.025       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.57e+03    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.979       |
# |    value_loss           | 5.5e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71.6        |
# |    ep_rew_mean          | -282        |
# | time/                   |             |
# |    fps                  | 1539        |
# |    iterations           | 23          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008099135 |
# |    clip_fraction        | 0.0839      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.125       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.28e+03    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.986       |
# |    value_loss           | 8e+03       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71          |
# |    ep_rew_mean          | -292        |
# | time/                   |             |
# |    fps                  | 1537        |
# |    iterations           | 24          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009715544 |
# |    clip_fraction        | 0.0955      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.339       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.98e+03    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 0.978       |
# |    value_loss           | 2.27e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 77.9         |
# |    ep_rew_mean          | -303         |
# | time/                   |              |
# |    fps                  | 1537         |
# |    iterations           | 25           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0072501446 |
# |    clip_fraction        | 0.0486       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.79        |
# |    explained_variance   | 0.288        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.86e+03     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00908     |
# |    std                  | 0.973        |
# |    value_loss           | 5.52e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.1        |
# |    ep_rew_mean          | -267        |
# | time/                   |             |
# |    fps                  | 1539        |
# |    iterations           | 26          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.006356368 |
# |    clip_fraction        | 0.0736      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.242       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.57e+03    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00825    |
# |    std                  | 0.966       |
# |    value_loss           | 4.16e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 75.4       |
# |    ep_rew_mean          | -232       |
# | time/                   |            |
# |    fps                  | 1542       |
# |    iterations           | 27         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.00789583 |
# |    clip_fraction        | 0.0661     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.77      |
# |    explained_variance   | 0.389      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.03e+03   |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.00932   |
# |    std                  | 0.964      |
# |    value_loss           | 5.36e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 78.6         |
# |    ep_rew_mean          | -222         |
# | time/                   |              |
# |    fps                  | 1543         |
# |    iterations           | 28           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0141884275 |
# |    clip_fraction        | 0.141        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.76        |
# |    explained_variance   | 0.309        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.04e+03     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0133      |
# |    std                  | 0.961        |
# |    value_loss           | 2.58e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 67.3        |
# |    ep_rew_mean          | -161        |
# | time/                   |             |
# |    fps                  | 1543        |
# |    iterations           | 29          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.008905307 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0.433       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 310         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.959       |
# |    value_loss           | 1.18e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.1        |
# |    ep_rew_mean          | -196        |
# | time/                   |             |
# |    fps                  | 1543        |
# |    iterations           | 30          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.011658372 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.33e+03    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00878    |
# |    std                  | 0.965       |
# |    value_loss           | 3.12e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.2        |
# |    ep_rew_mean          | -193        |
# | time/                   |             |
# |    fps                  | 1541        |
# |    iterations           | 31          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.008985555 |
# |    clip_fraction        | 0.0576      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.212       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.24e+03    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00961    |
# |    std                  | 0.96        |
# |    value_loss           | 4.06e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.2        |
# |    ep_rew_mean          | -193        |
# | time/                   |             |
# |    fps                  | 1541        |
# |    iterations           | 32          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.010146251 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0.294       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.87e+03    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 0.955       |
# |    value_loss           | 3.12e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 56.2       |
# |    ep_rew_mean          | -193       |
# | time/                   |            |
# |    fps                  | 1542       |
# |    iterations           | 33         |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.02517261 |
# |    clip_fraction        | 0.273      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.72      |
# |    explained_variance   | -0.218     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 88         |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0226    |
# |    std                  | 0.943      |
# |    value_loss           | 231        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.1        |
# |    ep_rew_mean          | -248        |
# | time/                   |             |
# |    fps                  | 1545        |
# |    iterations           | 34          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.016518319 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.666       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.5        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0239     |
# |    std                  | 0.931       |
# |    value_loss           | 84.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -287        |
# | time/                   |             |
# |    fps                  | 1545        |
# |    iterations           | 35          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.006302575 |
# |    clip_fraction        | 0.0507      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.239       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.03e+03    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00832    |
# |    std                  | 0.931       |
# |    value_loss           | 4.58e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 112         |
# |    ep_rew_mean          | -287        |
# | time/                   |             |
# |    fps                  | 1545        |
# |    iterations           | 36          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.008447288 |
# |    clip_fraction        | 0.0792      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.335       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.49e+03    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0126     |
# |    std                  | 0.929       |
# |    value_loss           | 3.6e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 62         |
# |    ep_rew_mean          | -221       |
# | time/                   |            |
# |    fps                  | 1544       |
# |    iterations           | 37         |
# |    time_elapsed         | 49         |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.00984984 |
# |    clip_fraction        | 0.108      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.69      |
# |    explained_variance   | 0.217      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 645        |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0134    |
# |    std                  | 0.928      |
# |    value_loss           | 4.2e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.5        |
# |    ep_rew_mean          | -208        |
# | time/                   |             |
# |    fps                  | 1544        |
# |    iterations           | 38          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008699055 |
# |    clip_fraction        | 0.0908      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.68       |
# |    explained_variance   | 0.361       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 815         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 0.924       |
# |    value_loss           | 3.64e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 67.6      |
# |    ep_rew_mean          | -189      |
# | time/                   |           |
# |    fps                  | 1544      |
# |    iterations           | 39        |
# |    time_elapsed         | 51        |
# |    total_timesteps      | 79872     |
# | train/                  |           |
# |    approx_kl            | 0.0079657 |
# |    clip_fraction        | 0.0696    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.68     |
# |    explained_variance   | 0.259     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.14e+03  |
# |    n_updates            | 380       |
# |    policy_gradient_loss | -0.00966  |
# |    std                  | 0.927     |
# |    value_loss           | 3.81e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 65.9       |
# |    ep_rew_mean          | -248       |
# | time/                   |            |
# |    fps                  | 1543       |
# |    iterations           | 40         |
# |    time_elapsed         | 53         |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.00942899 |
# |    clip_fraction        | 0.0813     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.69      |
# |    explained_variance   | 0.332      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.18e+03   |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0117    |
# |    std                  | 0.927      |
# |    value_loss           | 1.93e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 80.1        |
# |    ep_rew_mean          | -299        |
# | time/                   |             |
# |    fps                  | 1544        |
# |    iterations           | 41          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.004113204 |
# |    clip_fraction        | 0.0253      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.304       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.73e+03    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0047     |
# |    std                  | 0.93        |
# |    value_loss           | 6e+03       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 66.2        |
# |    ep_rew_mean          | -268        |
# | time/                   |             |
# |    fps                  | 1544        |
# |    iterations           | 42          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.006416751 |
# |    clip_fraction        | 0.0328      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.358       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.48e+03    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00694    |
# |    std                  | 0.93        |
# |    value_loss           | 9.85e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 66.2        |
# |    ep_rew_mean          | -268        |
# | time/                   |             |
# |    fps                  | 1543        |
# |    iterations           | 43          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.004137331 |
# |    clip_fraction        | 0.0277      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.398       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3e+03     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00609    |
# |    std                  | 0.929       |
# |    value_loss           | 3.04e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 87.2        |
# |    ep_rew_mean          | -242        |
# | time/                   |             |
# |    fps                  | 1543        |
# |    iterations           | 44          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.015828982 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.68       |
# |    explained_variance   | 0.112       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 448         |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.921       |
# |    value_loss           | 2.48e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 86.7         |
# |    ep_rew_mean          | -238         |
# | time/                   |              |
# |    fps                  | 1544         |
# |    iterations           | 45           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0045790235 |
# |    clip_fraction        | 0.0226       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.67        |
# |    explained_variance   | 0.539        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 360          |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00592     |
# |    std                  | 0.92         |
# |    value_loss           | 3.95e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | -223        |
# | time/                   |             |
# |    fps                  | 1545        |
# |    iterations           | 46          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.008657992 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.66       |
# |    explained_variance   | -0.248      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 512         |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00901    |
# |    std                  | 0.913       |
# |    value_loss           | 1.56e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 108          |
# |    ep_rew_mean          | -247         |
# | time/                   |              |
# |    fps                  | 1544         |
# |    iterations           | 47           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0045963987 |
# |    clip_fraction        | 0.0324       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.64        |
# |    explained_variance   | 0.352        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 507          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00804     |
# |    std                  | 0.904        |
# |    value_loss           | 1.43e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 108         |
# |    ep_rew_mean          | -247        |
# | time/                   |             |
# |    fps                  | 1545        |
# |    iterations           | 48          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009381281 |
# |    clip_fraction        | 0.0774      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.64       |
# |    explained_variance   | 0.333       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.49e+03    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.905       |
# |    value_loss           | 3.91e+03    |
# -----------------------------------------
# Eval num_timesteps=100000, episode_reward=-20100.13 +/- 24444.90
# Episode length: 40008.20 +/- 48984.73
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 4e+04      |
# |    mean_reward          | -2.01e+04  |
# | time/                   |            |
# |    total_timesteps      | 100000     |
# | train/                  |            |
# |    approx_kl            | 0.04626248 |
# |    clip_fraction        | 0.197      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.62      |
# |    explained_variance   | 0.63       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 49.8       |
# |    n_updates            | 480        |
# |    policy_gradient_loss | 0.00109    |
# |    std                  | 0.895      |
# |    value_loss           | 138        |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 101      |
# |    ep_rew_mean     | -226     |
# | time/              |          |
# |    fps             | 855      |
# |    iterations      | 49       |
# |    time_elapsed    | 117      |
# |    total_timesteps | 100352   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | -264        |
# | time/                   |             |
# |    fps                  | 862         |
# |    iterations           | 50          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.007626692 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.463       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 474         |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00416    |
# |    std                  | 0.896       |
# |    value_loss           | 3.31e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 97.4        |
# |    ep_rew_mean          | -256        |
# | time/                   |             |
# |    fps                  | 870         |
# |    iterations           | 51          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.008262467 |
# |    clip_fraction        | 0.0668      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.411       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.91e+03    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00928    |
# |    std                  | 0.895       |
# |    value_loss           | 3.3e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.9        |
# |    ep_rew_mean          | -263        |
# | time/                   |             |
# |    fps                  | 877         |
# |    iterations           | 52          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.009578811 |
# |    clip_fraction        | 0.0869      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.58        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 851         |
# |    n_updates            | 510         |
# ...
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.813      |
# |    explained_variance   | 0.676       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.4        |
# |    n_updates            | 3180        |
# |    policy_gradient_loss | 0.0143      |
# |    std                  | 0.362       |
# |    value_loss           | 50.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 542         |
# |    ep_rew_mean          | -766        |
# | time/                   |             |
# |    fps                  | 948         |
# |    iterations           | 320         |
# |    time_elapsed         | 690         |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.034940444 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.798      |
# |    explained_variance   | 0.82        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28          |
# |    n_updates            | 3190        |
# |    policy_gradient_loss | -0.000356   |
# |    std                  | 0.359       |
# |    value_loss           | 29          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 542         |
# |    ep_rew_mean          | -766        |
# | time/                   |             |
# |    fps                  | 950         |
# |    iterations           | 321         |
# |    time_elapsed         | 691         |
# |    total_timesteps      | 657408      |
# | train/                  |             |
# |    approx_kl            | 0.042437673 |
# |    clip_fraction        | 0.35        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.796      |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.25        |
# |    n_updates            | 3200        |
# |    policy_gradient_loss | 0.0288      |
# |    std                  | 0.36        |
# |    value_loss           | 3.93        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 542         |
# |    ep_rew_mean          | -766        |
# | time/                   |             |
# |    fps                  | 951         |
# |    iterations           | 322         |
# |    time_elapsed         | 693         |
# |    total_timesteps      | 659456      |
# | train/                  |             |
# |    approx_kl            | 0.006938216 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.795      |
# |    explained_variance   | 0.457       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 181         |
# |    n_updates            | 3210        |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.36        |
# |    value_loss           | 176         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 724         |
# |    ep_rew_mean          | -899        |
# | time/                   |             |
# |    fps                  | 952         |
# |    iterations           | 323         |
# |    time_elapsed         | 694         |
# |    total_timesteps      | 661504      |
# | train/                  |             |
# |    approx_kl            | 0.012569223 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.78       |
# |    explained_variance   | 0.585       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 73          |
# |    n_updates            | 3220        |
# |    policy_gradient_loss | -0.004      |
# |    std                  | 0.355       |
# |    value_loss           | 58.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 724          |
# |    ep_rew_mean          | -899         |
# | time/                   |              |
# |    fps                  | 953          |
# |    iterations           | 324          |
# |    time_elapsed         | 695          |
# |    total_timesteps      | 663552       |
# | train/                  |              |
# |    approx_kl            | 0.0076543344 |
# |    clip_fraction        | 0.0559       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.764       |
# |    explained_variance   | 0.7          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 718          |
# |    n_updates            | 3230         |
# |    policy_gradient_loss | -0.00791     |
# |    std                  | 0.355        |
# |    value_loss           | 1.2e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 701         |
# |    ep_rew_mean          | -863        |
# | time/                   |             |
# |    fps                  | 954         |
# |    iterations           | 325         |
# |    time_elapsed         | 697         |
# |    total_timesteps      | 665600      |
# | train/                  |             |
# |    approx_kl            | 0.036155023 |
# |    clip_fraction        | 0.373       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.76       |
# |    explained_variance   | -0.0179     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.3        |
# |    n_updates            | 3240        |
# |    policy_gradient_loss | -0.026      |
# |    std                  | 0.353       |
# |    value_loss           | 112         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 698          |
# |    ep_rew_mean          | -851         |
# | time/                   |              |
# |    fps                  | 955          |
# |    iterations           | 326          |
# |    time_elapsed         | 698          |
# |    total_timesteps      | 667648       |
# | train/                  |              |
# |    approx_kl            | 0.0035190973 |
# |    clip_fraction        | 0.0205       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.757       |
# |    explained_variance   | 0.233        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.98e+03     |
# |    n_updates            | 3250         |
# |    policy_gradient_loss | -0.00162     |
# |    std                  | 0.353        |
# |    value_loss           | 8.82e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 681          |
# |    ep_rew_mean          | -829         |
# | time/                   |              |
# |    fps                  | 956          |
# |    iterations           | 327          |
# |    time_elapsed         | 699          |
# |    total_timesteps      | 669696       |
# | train/                  |              |
# |    approx_kl            | 0.0061729825 |
# |    clip_fraction        | 0.0334       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.757       |
# |    explained_variance   | 0.437        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 637          |
# |    n_updates            | 3260         |
# |    policy_gradient_loss | -0.00667     |
# |    std                  | 0.353        |
# |    value_loss           | 1.84e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 705         |
# |    ep_rew_mean          | -825        |
# | time/                   |             |
# |    fps                  | 957         |
# |    iterations           | 328         |
# |    time_elapsed         | 701         |
# |    total_timesteps      | 671744      |
# | train/                  |             |
# |    approx_kl            | 0.013620475 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.757      |
# |    explained_variance   | 0.338       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 403         |
# |    n_updates            | 3270        |
# |    policy_gradient_loss | -0.0184     |
# |    std                  | 0.353       |
# |    value_loss           | 1.3e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 705         |
# |    ep_rew_mean          | -825        |
# | time/                   |             |
# |    fps                  | 959         |
# |    iterations           | 329         |
# |    time_elapsed         | 702         |
# |    total_timesteps      | 673792      |
# | train/                  |             |
# |    approx_kl            | 0.007469175 |
# |    clip_fraction        | 0.0752      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.759      |
# |    explained_variance   | 0.603       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 105         |
# |    n_updates            | 3280        |
# |    policy_gradient_loss | -0.00597    |
# |    std                  | 0.354       |
# |    value_loss           | 565         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 705         |
# |    ep_rew_mean          | -825        |
# | time/                   |             |
# |    fps                  | 960         |
# |    iterations           | 330         |
# |    time_elapsed         | 703         |
# |    total_timesteps      | 675840      |
# | train/                  |             |
# |    approx_kl            | 0.013488596 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.754      |
# |    explained_variance   | 0.813       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13          |
# |    n_updates            | 3290        |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.351       |
# |    value_loss           | 35          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 705         |
# |    ep_rew_mean          | -825        |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 331         |
# |    time_elapsed         | 705         |
# |    total_timesteps      | 677888      |
# | train/                  |             |
# |    approx_kl            | 0.032123037 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.74       |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.972       |
# |    n_updates            | 3300        |
# |    policy_gradient_loss | -0.016      |
# |    std                  | 0.349       |
# |    value_loss           | 6.43        |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[106], line 27
#      16 # model.load("logs/best_model/best_model.zip",env=env)  # Load the best model
#      17 eval_callback = EvalCallback(
#      18     env,
#      19     best_model_save_path='./logs/best_model2/',
#    (...)
#      24     n_eval_episodes=5,  # 每次评估5个episode
#      25 )
# ---> 27 model.learn(total_timesteps=5000000,callback=eval_callback)
#      28 # env.save("vec_env.pkl")  # Save the environment state
#      29 # vec_env = model.get_env()
#      30 # obs = vec_env.reset()
#    (...)
#      33 #     obs, reward, dones, info = vec_env.step(action)
#      34     # vec_env.render()
#      37 env.close()
#
# File g:\anaconda\envs\RL\lib\site-packages\stable_baselines3\ppo\ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)
#     309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File g:\anaconda\envs\RL\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:335, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     333     if log_interval is not None and iteration % log_interval == 0:
#     334         assert self.ep_info_buffer is not None
# --> 335         self.dump_logs(iteration)
#     337     self.train()
#     339 callback.on_training_end()
#
# File g:\anaconda\envs\RL\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:298, in OnPolicyAlgorithm.dump_logs(self, iteration)
#     296 if len(self.ep_success_buffer) > 0:
#     297     self.logger.record("rollout/success_rate", safe_mean(self.ep_success_buffer))
# --> 298 self.logger.dump(step=self.num_timesteps)
#
# File g:\anaconda\envs\RL\lib\site-packages\stable_baselines3\common\logger.py:540, in Logger.dump(self, step)
#     538 for _format in self.output_formats:
#     539     if isinstance(_format, KVWriter):
# --> 540         _format.write(self.name_to_value, self.name_to_excluded, step)
#     542 self.name_to_value.clear()
#     543 self.name_to_count.clear()
#
# File g:\anaconda\envs\RL\lib\site-packages\stable_baselines3\common\logger.py:238, in HumanOutputFormat.write(self, key_values, key_excluded, step)
#     236     tqdm.write("\n".join(lines) + "\n", file=sys.stdout, end="")
#     237 else:
# --> 238     self.file.write("\n".join(lines) + "\n")
#     240 # Flush the output to the file
#     241 self.file.flush()
#
# File g:\anaconda\envs\RL\lib\site-packages\ipykernel\iostream.py:694, in OutStream.write(self, string)
#     692     self.pub_thread.schedule(self._flush)
#     693 else:
# --> 694     self._schedule_flush()
#     696 return len(string)
#
# File g:\anaconda\envs\RL\lib\site-packages\ipykernel\iostream.py:590, in OutStream._schedule_flush(self)
#     587 def _schedule_in_thread():
#     588     self._io_loop.call_later(self.flush_interval, self._flush)
# --> 590 self.pub_thread.schedule(_schedule_in_thread)
#
# File g:\anaconda\envs\RL\lib\site-packages\ipykernel\iostream.py:267, in IOPubThread.schedule(self, f)
#     265     self._events.append(f)
#     266     # wake event thread (message content is ignored)
# --> 267     self._event_pipe.send(b"")
#     268 else:
#     269     f()
#
# File g:\anaconda\envs\RL\lib\site-packages\zmq\sugar\socket.py:701, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     694         data = zmq.Frame(
#     695             data,
#     696             track=track,
#     697             copy=copy or None,
#     698             copy_threshold=self.copy_threshold,
#     699         )
#     700     data.group = group
# --> 701 return super().send(data, flags=flags, copy=copy, track=track)
#
# File _zmq.py:1092, in zmq.backend.cython._zmq.Socket.send()
#
# File _zmq.py:1140, in zmq.backend.cython._zmq.Socket.send()
#
# File _zmq.py:1339, in zmq.backend.cython._zmq._send_copy()
#
# File _zmq.py:160, in zmq.backend.cython._zmq._check_rc()
#
# KeyboardInterrupt:

# %%
env = CustomEnv()
model.load("logs/best_model/best_model.zip")  # Load the best model
obs,_ = env.reset()
print(obs)
for i in range(1000000):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, teminated,_, info = env.step(action)
    print(action,info["distance_to_goal"])
    print(obs)
    print(action)
    print("Reward:", reward)
    print(env.robot_position)
    env.render()
    time.sleep(0.6)  # Control the frame rate
    if teminated:
        env.close()
        break
        print("Resetting environment")
# Out:
# [9.0852375  9.894207   8.377251   4.4080257  0.53639656 0.8593423
#  7.7813177  9.61936    9.844867   1.698531   0.30505937 0.40137142
#  1.4154787  3.7049382  3.8755114  7.5925903  2.2259498  8.708509
#  7.7482805  6.1647043  4.84906    0.        ]
# [-0.18751201 -0.15672167] 5.478071359209566
# [9.028984   9.84719    8.377251   4.4080257  0.59038067 0.8593423
#  7.7813177  9.61936    9.844867   1.698531   0.30505937 0.40137142
#  1.4154787  3.7049382  3.8755114  7.5925903  2.2259498  8.708509
#  7.7482805  6.1647043  4.84906    0.        ]
# [-0.18751201 -0.15672167]
# Reward: -80.27972545117694
# [9.02898395 9.84719002]
# [-0.18692452 -0.15491629] 5.425486731162481
# [8.972907   9.800715   8.377251   4.4080257  0.6479595  0.8593423
#  7.7813177  9.61936    9.844867   1.698531   0.30505937 0.40137142
#  1.4154787  3.7049382  3.8755114  7.5925903  2.2259498  8.708509
#  7.7482805  6.1647043  4.84906    0.01      ]
# [-0.18692452 -0.15491629]
# Reward: -68.8047253062037
# [8.97290659 9.80071514]
# [-0.18639484 -0.1530364 ] 5.373951795991144
# [8.916988   9.754805   8.377251   4.4080257  0.70812255 0.8593423
#  7.7813177  9.61936    9.844867   1.698531   0.30505937 0.40137142
#  1.4154787  3.7049382  3.8755114  7.5925903  2.2259498  8.708509
#  7.7482805  6.1647043  4.84906    0.02      ]
# [-0.18639484 -0.1530364 ]
# Reward: -56.81408854423675
# [8.91698814 9.75480421]
# [-0.18584704 -0.15110756] 5.323492555243249
# [8.861234   9.709472   8.377251   4.4080257  0.77012134 0.8593423
#  7.7813177  9.61936    9.844867   1.698531   0.30505937 0.40137142
#  1.4154787  3.7049382  3.8755114  7.5925903  2.2259498  8.708509
#  7.7482805  6.1647043  4.84906    0.03      ]
# [-0.18584704 -0.15110756]
# Reward: -44.45736751146615
# [8.86123402 9.70947194]
# [-0.18528956 -0.1491388 ] 5.274131931120854
# [8.805647   9.66473    8.377251   4.4080257  0.83341336 0.8593423
#  7.7813177  9.61936    9.844867   1.698531   0.30505937 0.40137142
#  1.4154787  3.7049382  3.8755114  7.5925903  2.2259498  8.708509
#  7.7482805  6.1647043  4.84906    0.04      ]
# [-0.18528956 -0.1491388 ]
# Reward: -31.84290249562553
# [8.80564715 9.66473031]
# [-0.18472847 -0.14713679] 5.2258905643866305
# [8.750229   9.620589   8.377251   4.4080257  0.89760226 0.8593423
#  7.7813177  9.61936    9.844867   1.698531   0.30505937 0.40137142
#  1.4154787  3.7049382  3.8755114  7.5925903  2.2259498  8.708509
#  7.7482805  6.1647043  4.84906    0.05      ]
# [-0.18472847 -0.14713679]
# Reward: -19.049887595831542
# [8.75022861 9.62058927]
# [-0.18416844 -0.14510672] 5.178787359369218
# [8.694978   9.577057   8.377251   4.4080257  0.96239495 0.8593423
#  7.7813177  9.61936    9.844867   1.698531   0.30505937 0.40137142
#  1.4154787  3.7049382  3.8755114  7.5925903  2.2259498  8.708509
#  7.7482805  6.1647043  4.84906    0.06      ]
# [-0.18416844 -0.14510672]
# Reward: -6.136887075466648
# [8.69497807 9.57705725]
# [-0.18361294 -0.14305244] 5.132839911118478
# [8.6398945  9.534142   8.377251   4.4080257  1.0275717  0.8593423
#  7.7813177  9.61936    9.844867   1.698531   0.30505937 0.40137142
#  1.4154787  3.7049382  3.8755114  7.5925903  2.2259498  8.708509
#  7.7482805  6.1647043  4.84906    0.07      ]
# [-0.18361294 -0.14305244]
# Reward: 1.337897930029584
# [8.63989419 9.53414151]
# [-0.18306458 -0.14097719] 5.088064726866478
# [8.584975   9.491848   8.377251   4.4080257  1.0929661  0.8593423
#  7.7813177  9.61936    9.844867   1.698531   0.30505937 0.40137142
#  1.4154787  3.7049382  3.8755114  7.5925903  2.2259498  8.708509
#  7.7482805  6.1647043  4.84906    0.08      ]
# [-0.18306458 -0.14097719]
# Reward: 1.2910073700799956
# [8.58497481 9.49184836]
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# g:\anaconda\envs\RL\lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import cv2
import numpy as np
import mediapipe as mp
from segment_anything import sam_model_registry, SamPredictor


img = cv2.imread('../test.jpg')
sam = sam_model_registry["vit_b"](checkpoint="../sam_vit_b_01ec64.pth")
predictor = SamPredictor(sam)
predictor.set_image(img)


mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

hands = mp_hands.Hands(static_image_mode=False,
    max_num_hands=2,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5
)

rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
results = hands.process(rgb)
if results.multi_hand_landmarks:
    hand_landmarks = results.multi_hand_landmarks[0]
    x = hand_landmarks.landmark[0].x
    y =hand_landmarks.landmark[0].y
point_coords = np.array([[x, y]])
print(point_coords.shape)
point_labels = np.array([1])   # 1=前景, 0=背景

masks, scores, logits = predictor.predict(
    point_coords=point_coords,
    point_labels=point_labels,
    multimask_output=True,  # 返回多候选，配合 scores/IoU 选最优
)
best = masks[scores.argmax()]  # 挑最优掩膜



hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

lower = np.array([0, 30, 60], dtype="uint8")
upper = np.array([20, 150, 255], dtype="uint8")
mask = cv2.inRange(hsv, lower, upper)

cv2.imshow("mask", best)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# g:\anaconda\envs\RL\lib\site-packages\segment_anything\build_sam.py:105: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(f)
# (1, 2)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[11], line 47
#      44 upper = np.array([20, 150, 255], dtype="uint8")
#      45 mask = cv2.inRange(hsv, lower, upper)
# ---> 47 cv2.imshow("mask", best)
#      48 cv2.waitKey(0)
#      49 cv2.destroyAllWindows()
#
# error: OpenCV(4.11.0) :-1: error: (-5:Bad argument) in function 'imshow'
# > Overload resolution failed:
# >  - mat data type = bool is not supported
# >  - Expected Ptr<cv::cuda::GpuMat> for argument 'mat'
# >  - Expected Ptr<cv::UMat> for argument 'mat'

# %%
import json

with open(r'C:\Users\admin\Desktop\科研\RL\src\logs\best_model_sac14\env_args.json', 'r') as f:
    data = json.load(f)
    print(data)
# Out:
# {'grid_size': 10, 'distance_threshold_penalty': 4, 'distance_threshold_collision': 1.5, 'penalty_factor': 5, 'distance_reward_factor': 5, 'smooth_action_penalty': 1, 'max_steps': 40, 'margin': 0.1, 'reward_step': 4, 'reward_max_step': 50, 'reward_bound': -400, 'reward_arm': -200, 'reward_hand': -200}
